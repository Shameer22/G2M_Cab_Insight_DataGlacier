# %% [markdown]
# ##Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime

# %%
url1 = "https://raw.githubusercontent.com/Shameer22/DataSets/main/Cab_Data.csv"
CabData = pd.read_csv(url1)
CabData
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# ...

# %%
url2 = "https://raw.githubusercontent.com/Shameer22/DataSets/main/City.csv"
CityData = pd.read_csv(url2)
CityData
# Out:
#                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# 19         BOSTON MA     248,968     80,021

# %%
url3 = "https://raw.githubusercontent.com/Shameer22/DataSets/main/Customer_ID.csv"
CustomerID = pd.read_csv(url3)
CustomerID
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28               10813
# 1            27703    Male   27                9237
# 2            28712    Male   53               11242
# 3            28020    Male   23               23327
# 4            27182    Male   33                8536
# ...            ...     ...  ...                 ...
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128
#
# [49171 rows x 4 columns]

# %%
url4 = "https://raw.githubusercontent.com/Shameer22/DataSets/main/Transaction_ID.csv"
TransactionID = pd.read_csv(url4)
TransactionID
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 0             10000011        29290         Card
# 1             10000012        27703         Card
# 2             10000013        28712         Cash
# 3             10000014        28020         Cash
# 4             10000015        27182         Card
# ...                ...          ...          ...
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card
#
# [440098 rows x 3 columns]

# %% [markdown]
# ##EDA

# %%
CabData.head()
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
CabData.info
# Out:
# <bound method DataFrame.info of         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# ...

# %%
CabData.shape
# Out:
# (359392, 7)

# %%
CityData.head()
# Out:
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247

# %%
CityData.info
# Out:
# <bound method DataFrame.info of                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# ...

# %%
CityData.shape
# Out:
# (20, 3)

# %%
CustomerID.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536

# %%
CustomerID.info
# Out:
# <bound method DataFrame.info of        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28               10813
# 1            27703    Male   27                9237
# 2            28712    Male   53               11242
# 3            28020    Male   23               23327
# 4            27182    Male   33                8536
# ...            ...     ...  ...                 ...
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128
#
# [49171 rows x 4 columns]>

# %%
CustomerID.shape
# Out:
# (49171, 4)

# %%
TransactionID.head()
# Out:
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card

# %%
TransactionID.info
# Out:
# <bound method DataFrame.info of         Transaction ID  Customer ID Payment_Mode
# 0             10000011        29290         Card
# 1             10000012        27703         Card
# 2             10000013        28712         Cash
# 3             10000014        28020         Cash
# 4             10000015        27182         Card
# ...                ...          ...          ...
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card
#
# [440098 rows x 3 columns]>

# %%
TransactionID.shape
# Out:
# (440098, 3)

# %%
CabData.isnull().sum()
# Out:
# Transaction ID    0
# Date of Travel    0
# Company           0
# City              0
# KM Travelled      0
# Price Charged     0
# Cost of Trip      0
# dtype: int64

# %%
CityData.isnull().sum()
# Out:
# City          0
# Population    0
# Users         0
# dtype: int64

# %%
CustomerID.isnull().sum()
# Out:
# Customer ID           0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# dtype: int64

# %%
TransactionID.isnull().sum()
# Out:
# Transaction ID    0
# Customer ID       0
# Payment_Mode      0
# dtype: int64

# %%
for col in CabData.columns:
    if ' ' in col:
        CabData = CabData.rename(columns={col:col.replace(' ','_')})

# %%
for col in TransactionID.columns:
    if ' ' in col:
        TransactionID = TransactionID.rename(columns={col:col.replace(' ','_')})

# %%
for col in CustomerID.columns:
    if ' ' in col:
        CustomerID = CustomerID.rename(columns={col:col.replace(' ','_')})

# %%
from datetime import datetime, timedelta
def to_date_format(n):
    date_str =(datetime(1899,12,30) + timedelta(n-1)).strftime("%d-%m-%Y")
    date_date =  datetime.strptime(date_str, "%d-%m-%Y")
    return date_date

# %%
CabData['Date_of_Travel'] = CabData['Date_of_Travel'].apply(lambda x:to_date_format(x))

# %%
CabData.head()
# Out:
#    Transaction_ID Date_of_Travel   Company        City  KM_Travelled  \
# 0        10000011     2016-01-07  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-01-05  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-01-01  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-01-06  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-01-02  Pink Cab  ATLANTA GA          8.73
#
#    Price_Charged  Cost_of_Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
months=[]
years =[]
for i in range(len(CabData['Date_of_Travel'])):
    months.append(CabData['Date_of_Travel'][i].month)
    years.append(CabData['Date_of_Travel'][i].year)
CabData['Month'] = months
CabData['Year'] = years

CabData.drop('Date_of_Travel', axis=1, inplace=True)

# %% [markdown]
# ##Splitting of Dataset

# %%
Pink = CabData[CabData['Company']=='Pink Cab']
Yellow = CabData[CabData['Company']=='Yellow Cab']

# %%
Pink.head()
# Out:
#    Transaction_ID   Company        City  KM_Travelled  Price_Charged  \
# 0        10000011  Pink Cab  ATLANTA GA         30.45         370.95
# 1        10000012  Pink Cab  ATLANTA GA         28.62         358.52
# 2        10000013  Pink Cab  ATLANTA GA          9.04         125.20
# 3        10000014  Pink Cab  ATLANTA GA         33.17         377.40
# 4        10000015  Pink Cab  ATLANTA GA          8.73         114.62
#
#    Cost_of_Trip  Month  Year
# 0       313.635      1  2016
# 1       334.854      1  2016
# 2        97.632      1  2016
# 3       351.602      1  2016
# 4        97.776      1  2016

# %%
Yellow.head()
# Out:
#      Transaction_ID     Company        City  KM_Travelled  Price_Charged  \
# 233        10000384  Yellow Cab  ATLANTA GA         33.93        1341.17
# 234        10000385  Yellow Cab  ATLANTA GA         42.18        1412.06
# 235        10000386  Yellow Cab  ATLANTA GA         10.60         364.62
# 236        10000387  Yellow Cab  ATLANTA GA         26.75         838.00
# 237        10000388  Yellow Cab  ATLANTA GA         46.02        1540.61
#
#      Cost_of_Trip  Month  Year
# 233      464.1624      1  2016
# 234      516.2832      1  2016
# 235      132.2880      1  2016
# 236      333.8400      1  2016
# 237      596.4192      1  2016

# %% [markdown]
# ##Transaction Analysis Monthly

# %%
plot = CabData[CabData.Company=='Pink Cab'].groupby(['Month']).Transaction_ID.count()
plot
# Out:
# Month
# 1      4825
# 2      3392
# 3      4228
# 4      4140
# 5      5023
# 6      5820
# 7      6585
# 8      8061
# 9      9647
# 10    10366
# 11    11324
# 12    11300
# Name: Transaction_ID, dtype: int64

# %%
plt.figure(figsize=(14,6))
sns.barplot(x = plot.index,y = plot.values, palette = 'flare')
plt.title('Monthly Travel Frequency (Pink Cab)',fontsize = 11)
plt.xlabel('Month', fontsize = 11)
plt.ylabel('Values',fontsize = 11)
plt.show()

# %%
plot_a = CabData[CabData.Company=='Yellow Cab'].groupby(['Month']).Transaction_ID.count()
plot_a
# Out:
# Month
# 1     17468
# 2     14928
# 3     17516
# 4     17535
# 5     18809
# 6     18656
# 7     21074
# 8     24328
# 9     27356
# 10    29609
# 11    32609
# 12    34793
# Name: Transaction_ID, dtype: int64

# %%
plt.figure(figsize=(14,6))
sns.barplot(x = plot_a.index,y = plot_a.values, palette = 'Blues')
plt.title('Monthly Travel Frequency (Yellow Cab)',fontsize = 11)
plt.xlabel('Month', fontsize = 11)
plt.ylabel('Values',fontsize = 11)
plt.show()

# %% [markdown]
# > **Yellow Cab has most travels as compared to the Pink Cab**

# %% [markdown]
# ##Kilometers Travelled

# %%
OverallDistance = CabData['KM_Travelled'].describe()
PinkCabDistance = Pink['KM_Travelled'].describe()
YellowCabDistance = Yellow['KM_Travelled'].describe()

# %%
df = pd.DataFrame({'Overall': OverallDistance.values,
                  'Pink': PinkCabDistance.values,
                  'Yellow': YellowCabDistance.values}, index= ['Count', 'Mean', 'Std. Dev.', 'Min', '25%', '50%', '75%', 'Max'])
df
# Out:
#                  Overall          Pink         Yellow
# Count      359392.000000  84711.000000  274681.000000
# Mean           22.567254     22.559917      22.569517
# Std. Dev.      12.233526     12.231092      12.234298
# Min             1.900000      1.900000       1.900000
# 25%            12.000000     12.000000      11.990000
# 50%            22.440000     22.440000      22.440000
# 75%            32.960000     32.960000      32.960000
# Max            48.000000     48.000000      48.000000

# %%
kms_pink = sns.distplot(Pink['KM_Travelled'], kde=False, color='red', bins=70)
plt.title("Distribution of Kilometers Travelled in Pink Cab", fontsize=11, y=1.012)
plt.xlabel("KMs Travelled", labelpad=15)
plt.ylabel("Frequency", labelpad=15)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
kms_yellow = sns.distplot(Yellow['KM_Travelled'], kde=False, color='blue', bins=70)
plt.title("Distribution of Kilometers Travelled in Yellow Cab", fontsize=11, y=1.012)
plt.xlabel("KMs Travelled", labelpad=15)
plt.ylabel("Frequency", labelpad=15)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# > **From the plots, the rides are in between 2 kms to 48 kms**

# %% [markdown]
# ##Price Range

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(20,7))
sns.boxplot(Pink['Price_Charged'], ax=ax1, color='orange')
ax1.set_title('Pink Cab', fontsize=20)
sns.boxplot(Yellow['Price_Charged'], ax=ax2, color='green')
ax2.set_title('Yellow Cab', fontsize=20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# > **The price range of Pink Cab is less than Yellow Cab**
#
# > **The outliers are the use of high-end cars**

# %% [markdown]
# ##The Price and Distance Relation

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(20, 7))
sns.scatterplot(Pink['KM_Travelled'], Pink['Price_Charged'], ax=ax1, color='purple')
ax1.set_title('Price vs Distance in Pink Cab', fontsize=20)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=0, fontsize=15)

sns.scatterplot(Yellow['KM_Travelled'], Yellow['Price_Charged'], ax=ax2, color='magenta')
ax2.set_title('Price vs Distance in Yellow Cab', fontsize=20)
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=0, fontsize=15)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Pink['KM_Travelled'].corr(Pink['Price_Charged'])
# Out:
# 0.9277652782594856

# %%
Yellow['KM_Travelled'].corr(Yellow['Price_Charged'])
# Out:
# 0.859708629447849

# %% [markdown]
# > **The price of the rides depends on the distance travelled**
#
# > **The correlation is positive in both pink and yellow cabs**
#
# > **The price of yellow cab is higher as compared to the one of pink cab**

# %% [markdown]
# ##Number of Transactions in Each Cabs

# %%
plot1 = CabData[CabData.Company=='Pink Cab'].groupby('Year').Transaction_ID.count()
plot2 = CabData[CabData.Company=='Yellow Cab'].groupby('Year').Transaction_ID.count()
plt.figure(figsize=(14,6))
ax = plt.subplot(111)

ax.bar(plot1.index-0.2, plot1.values, width=0.4, color='pink', align='center',label='Pink Cab')
ax.bar(plot1.index+0.2, plot2.values, width=0.4, color='yellow', align='center',label='Yellow Cab')
plt.title("Pink cab vs Yellow cab",fontsize = 16)
plt.ylabel('Number of Transactions',fontsize = 14)
plt.xlabel('Year',fontsize = 14)
plt.legend()
plt.show()

# %% [markdown]
# > **The plot shows that the transactions for yellow cab is higher than the pink cab**

# %% [markdown]
# ###For Pink Cab

# %%
CabData[CabData.Company=='Pink Cab'].groupby('Year').Price_Charged.mean()
# Out:
# Year
# 2016    315.850071
# 2017    315.535059
# 2018    301.538134
# Name: Price_Charged, dtype: float64

# %%
CabData[CabData.Company=='Pink Cab'].groupby('Year').Cost_of_Trip.mean()
# Out:
# Year
# 2016    247.039209
# 2017    248.820917
# 2018    248.413839
# Name: Cost_of_Trip, dtype: float64

# %%
plot1 = CabData[CabData.Company=='Pink Cab'].groupby('Year').Transaction_ID.count()
plot3 = CabData[CabData.Company=='Pink Cab'].groupby('Year').Price_Charged.mean()
plot4 = CabData[CabData.Company=='Pink Cab'].groupby('Year').Cost_of_Trip.mean()
plt.figure(figsize=(14,6))

ax = plt.subplot(111)
ax.bar(plot1.index-0.2, plot4.values, width=0.4, color='pink', align='center',label='Cost of the Trip')
ax.bar(plot1.index+0.2, plot3.values, width=0.4, color='magenta', align='center',label='Price Charged')
plt.ylabel('Profit',fontsize=14)
plt.xlabel('Year',fontsize=14)
plt.title('Pink Cab', fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ###For Yellow Cab

# %%
CabData[CabData.Company=='Yellow Cab'].groupby('Year').Price_Charged.mean()
# Out:
# Year
# 2016    468.230462
# 2017    466.278438
# 2018    440.893159
# Name: Price_Charged, dtype: float64

# %%
CabData[CabData.Company=='Yellow Cab'].groupby('Year').Cost_of_Trip.mean()
# Out:
# Year
# 2016    298.536761
# 2017    297.861544
# 2018    297.442400
# Name: Cost_of_Trip, dtype: float64

# %%
plot1 = CabData[CabData.Company=='Yellow Cab'].groupby('Year').Transaction_ID.count()
plot3 = CabData[CabData.Company=='Yellow Cab'].groupby('Year').Price_Charged.mean()
plot4 = CabData[CabData.Company=='Yellow Cab'].groupby('Year').Cost_of_Trip.mean()
plt.figure(figsize=(14,6))

ax = plt.subplot(111)
ax.bar(plot1.index-0.2, plot4.values, width=0.4, color='yellow', align='center',label='Cost of the Trip')
ax.bar(plot1.index+0.2, plot3.values, width=0.4, color='orange', align='center',label='Price Charged')
plt.ylabel('Profit', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.title('Yellow Cab', fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# > **The yellow cab has the highest profit margin**

# %% [markdown]
# ##Cost of the Trips

# %% [markdown]
# ###For Pink Cab

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data=CabData, x=Pink["KM_Travelled"], y=Pink['Cost_of_Trip'], hue='City')
plt.title('Kilometers Travelled in Pink Cab',fontsize = 20)
plt.ylabel('Cost of trip',fontsize = 16)
plt.xlabel('KMs Travelled',fontsize = 16)
plt.show()

# %% [markdown]
# ###For Yellow Cab

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data=CabData, x=Yellow["KM_Travelled"], y=Yellow['Cost_of_Trip'], hue='City')
plt.title('Kilometers Travelled in Yellow Cab',fontsize = 20)
plt.ylabel('Cost of trip',fontsize = 16)
plt.xlabel('KMs Travelled',fontsize = 16)
plt.show()

# %% [markdown]
# > **The cost of trips for both the cabs are almost same**

# %% [markdown]
# ##Price Charged in Each Cities

# %% [markdown]
# ###For Pink Cab

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data=CabData, x=Pink["KM_Travelled"], y=Pink['Price_Charged'], hue="City")
plt.title('Kilometers Travelled in Pink Cab',fontsize = 20)
plt.ylabel('Price Charged',fontsize = 14)
plt.xlabel('KMs Travelled',fontsize = 14)
plt.show()

# %% [markdown]
# ###For Yellow Cab

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data=CabData, x=Yellow["KM_Travelled"], y=Yellow['Price_Charged'], hue="City")
plt.title('Kilometers Travelled in Yellow Cab',fontsize = 20)
plt.ylabel('Price Charged',fontsize = 14)
plt.xlabel('KMs Travelled',fontsize = 14)
plt.show()

# %% [markdown]
# > **Yellow cab is used in New York most frequently than other cities**
#
# > **There is same increase in prices with increase in distance for pink cab**
#
# > **The outliers are due to the high end cars and weather**

# %% [markdown]
# ##Master Data

# %%
left = CabData.set_index(['Transaction_ID'])
right = TransactionID.set_index(['Transaction_ID'])
data = left.join(right)
data.head()
# Out:
#                  Company        City  KM_Travelled  Price_Charged  \
# Transaction_ID
# 10000011        Pink Cab  ATLANTA GA         30.45         370.95
# 10000012        Pink Cab  ATLANTA GA         28.62         358.52
# 10000013        Pink Cab  ATLANTA GA          9.04         125.20
# 10000014        Pink Cab  ATLANTA GA         33.17         377.40
# 10000015        Pink Cab  ATLANTA GA          8.73         114.62
#
#                 Cost_of_Trip  Month  Year  Customer_ID Payment_Mode
# Transaction_ID
# 10000011             313.635      1  2016        29290         Card
# 10000012             334.854      1  2016        27703         Card
# 10000013              97.632      1  2016        28712         Cash
# 10000014             351.602      1  2016        28020         Cash
# 10000015              97.776      1  2016        27182         Card

# %%
left = data.set_index([data.index,'Customer_ID'])
right = CustomerID.set_index(['Customer_ID'])
data = left.join(right)
data.head()
# Out:
#                              Company        City  KM_Travelled  Price_Charged  \
# Transaction_ID Customer_ID
# 10000011       29290        Pink Cab  ATLANTA GA         30.45         370.95
# 10000012       27703        Pink Cab  ATLANTA GA         28.62         358.52
# 10000013       28712        Pink Cab  ATLANTA GA          9.04         125.20
# 10000014       28020        Pink Cab  ATLANTA GA         33.17         377.40
# 10000015       27182        Pink Cab  ATLANTA GA          8.73         114.62
#
#                             Cost_of_Trip  Month  Year Payment_Mode Gender  \
# Transaction_ID Customer_ID
# 10000011       29290             313.635      1  2016         Card   Male
# 10000012       27703             334.854      1  2016         Card   Male
# 10000013       28712              97.632      1  2016         Cash   Male
# 10000014       28020             351.602      1  2016         Cash   Male
# ...

# %%
left = data.set_index([data.index,'City'])
right = CityData.set_index(['City'])
data = left.join(right)
data.head()
# Out:
#                                         Company  KM_Travelled  Price_Charged  \
# Transaction_ID Customer_ID City
# 10000011       29290       ATLANTA GA  Pink Cab         30.45         370.95
# 10000012       27703       ATLANTA GA  Pink Cab         28.62         358.52
# 10000013       28712       ATLANTA GA  Pink Cab          9.04         125.20
# 10000014       28020       ATLANTA GA  Pink Cab         33.17         377.40
# 10000015       27182       ATLANTA GA  Pink Cab          8.73         114.62
#
#                                        Cost_of_Trip  Month  Year Payment_Mode  \
# Transaction_ID Customer_ID City
# 10000011       29290       ATLANTA GA       313.635      1  2016         Card
# 10000012       27703       ATLANTA GA       334.854      1  2016         Card
# 10000013       28712       ATLANTA GA        97.632      1  2016         Cash
# 10000014       28020       ATLANTA GA       351.602      1  2016         Cash
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 359392 entries, (10000011, 29290, 'ATLANTA GA') to (10440107, 52917, 'WASHINGTON DC')
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Company             359392 non-null  object
#  1   KM_Travelled        359392 non-null  float64
#  2   Price_Charged       359392 non-null  float64
#  3   Cost_of_Trip        359392 non-null  float64
#  4   Month               359392 non-null  int64
#  5   Year                359392 non-null  int64
#  6   Payment_Mode        359392 non-null  object
#  7   Gender              359392 non-null  object
#  8   Age                 359392 non-null  int64
#  9   Income_(USD/Month)  359392 non-null  int64
#  10  Population          359392 non-null  object
#  11  Users               359392 non-null  object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 48.2+ MB

# %%
data = data.reset_index()
data = data.rename(columns={'Income_(USD/Month)':'Income'})
city_users = data.groupby('City').Users.count()
city_users
# Out:
# City
# ATLANTA GA         7557
# AUSTIN TX          4896
# BOSTON MA         29692
# CHICAGO IL        56625
# DALLAS TX          7017
# DENVER CO          3825
# LOS ANGELES CA    48033
# MIAMI FL           6454
# NASHVILLE TN       3010
# NEW YORK NY       99885
# ORANGE COUNTY      3982
# PHOENIX AZ         2064
# PITTSBURGH PA      1313
# SACRAMENTO CA      2367
# SAN DIEGO CA      20488
# SEATTLE WA         7997
# SILICON VALLEY     8519
# TUCSON AZ          1931
# WASHINGTON DC     43737
# Name: Users, dtype: int64

# %% [markdown]
# ##Cab Users per City

# %%
labs = city_users.index
vals = city_users.values
figp, axp = plt.subplots(figsize=(18,13))
axp.pie(vals , labels=labs, autopct='%1.1f%%',shadow=True, startangle=90,)
axp.axis('equal')
plt.title('Cab Users per City')
plt.show()

# %% [markdown]
# > **New York has the highest cab users with 27.8% users followed by Chicago with 15.8& and Los Angeles with 13.4%**

# %% [markdown]
# ##Transactions Made per City

# %% [markdown]
# ###For Pink Cab

# %%
city_pink = data[data.Company=='Pink Cab'].groupby('City').Transaction_ID.count()
city_pink
# Out:
# City
# ATLANTA GA         1762
# AUSTIN TX          1868
# BOSTON MA          5186
# CHICAGO IL         9361
# DALLAS TX          1380
# DENVER CO          1394
# LOS ANGELES CA    19865
# MIAMI FL           2002
# NASHVILLE TN       1841
# NEW YORK NY       13967
# ORANGE COUNTY      1513
# PHOENIX AZ          864
# PITTSBURGH PA       682
# SACRAMENTO CA      1334
# SAN DIEGO CA      10672
# SEATTLE WA         2732
# SILICON VALLEY     3797
# TUCSON AZ           799
# WASHINGTON DC      3692
# Name: Transaction_ID, dtype: int64

# %%
labs = city_pink.index
vals = city_pink.values
figp, axp = plt.subplots(figsize=(20,10))
axp.pie(vals , labels=labs, autopct='%1.1f%%',shadow=True, startangle=90,)
axp.axis('equal')

plt.title('Transaction per City for Pink Cab')
plt.show()

# %% [markdown]
# ###For Yellow Cab

# %%
city_yellow = data[data.Company=='Yellow Cab'].groupby('City').Transaction_ID.count()
city_yellow
# Out:
# City
# ATLANTA GA         5795
# AUSTIN TX          3028
# BOSTON MA         24506
# CHICAGO IL        47264
# DALLAS TX          5637
# DENVER CO          2431
# LOS ANGELES CA    28168
# MIAMI FL           4452
# NASHVILLE TN       1169
# NEW YORK NY       85918
# ORANGE COUNTY      2469
# PHOENIX AZ         1200
# PITTSBURGH PA       631
# SACRAMENTO CA      1033
# SAN DIEGO CA       9816
# SEATTLE WA         5265
# SILICON VALLEY     4722
# TUCSON AZ          1132
# WASHINGTON DC     40045
# Name: Transaction_ID, dtype: int64

# %%
labs = city_yellow.index
vals = city_yellow.values
figp, axp = plt.subplots(figsize=(20,10))
axp.pie(vals , labels=labs, autopct='%1.1f%%',shadow=True, startangle=90,)
axp.axis('equal')

plt.title('Transaction per City for Yellow Cab')
plt.show()

# %% [markdown]
# > **Transaction in Los Angeles for Pink Cab is the highest of 23.5%**
#
# > **Transaction in New York for Yellow Cab is the highest of 31.3%**

# %% [markdown]
# ##Price Charged per Gender

# %% [markdown]
# ###For Pink Cab

# %%
gender_pink=data[data.Company=='Pink Cab'].groupby('Gender').Price_Charged.mean()
gender_pink
# Out:
# Gender
# Female    310.624823
# Male      310.940547
# Name: Price_Charged, dtype: float64

# %%
labs = gender_pink.index
vals = gender_pink.values
colors = ['pink', 'magenta']
figp, axp = plt.subplots(figsize=(10,7))
axp.pie(vals , labels=labs, autopct='%1.1f%%',shadow=True, startangle=90,colors = colors)
axp.axis('equal')

plt.title('Price Charged per Gender for Pink Cab')
plt.show()

# %% [markdown]
# ###For Yellow Cab

# %%
gender_yellow=data[data.Company=='Yellow Cab'].groupby('Gender').Price_Charged.mean()
gender_yellow
# Out:
# Gender
# Female    454.571538
# Male      460.821326
# Name: Price_Charged, dtype: float64

# %%
labs = gender_yellow.index
vals = gender_yellow.values
colors = ['yellow', 'orange']
figp, axp = plt.subplots(figsize=(10,7))
axp.pie(vals , labels=labs, autopct='%1.1f%%',shadow=True, startangle=90,colors = colors)
axp.axis('equal')

plt.title('Price Charged per Gender for Yellow Cab')
plt.show()

# %% [markdown]
# > **The prices charged per gender in pink cab is exactly equal and yellow cab is almost equal**

# %% [markdown]
# ##Customer Share per Gender

# %%
gender_cab=data.groupby(['Company','Gender']).Customer_ID.nunique()
gender_cab
# Out:
# Company     Gender
# Pink Cab    Female    14819
#             Male      17511
# Yellow Cab  Female    18394
#             Male      21502
# Name: Customer_ID, dtype: int64

# %%
labs = gender_cab.index
vals = gender_cab.values
colors = ['pink', 'magenta', 'yellow', 'orange']
figp, axp = plt.subplots(figsize=(10,7))
axp.pie(vals , labels=labs, autopct='%1.1f%%',shadow=True, startangle=90,colors=colors)
axp.axis('equal')

plt.title('Customer Share per Gender')
plt.show()

# %% [markdown]
# > **Yellow cab has the most female customers**

# %%
data['Margins'] = (data['Price_Charged']-data['Cost_of_Trip'])
data.head()
# Out:
#    Transaction_ID  Customer_ID        City   Company  KM_Travelled  \
# 0        10000011        29290  ATLANTA GA  Pink Cab         30.45
# 1        10000012        27703  ATLANTA GA  Pink Cab         28.62
# 2        10000013        28712  ATLANTA GA  Pink Cab          9.04
# 3        10000014        28020  ATLANTA GA  Pink Cab         33.17
# 4        10000015        27182  ATLANTA GA  Pink Cab          8.73
#
#    Price_Charged  Cost_of_Trip  Month  Year Payment_Mode Gender  Age  Income  \
# 0         370.95       313.635      1  2016         Card   Male   28   10813
# 1         358.52       334.854      1  2016         Card   Male   27    9237
# 2         125.20        97.632      1  2016         Cash   Male   53   11242
# 3         377.40       351.602      1  2016         Cash   Male   23   23327
# 4         114.62        97.776      1  2016         Card   Male   33    8536
#
#   Population     Users  Margins
# 0   814,885    24,701    57.315
# 1   814,885    24,701    23.666
# ...

# %%
data.tail()
# Out:
#         Transaction_ID  Customer_ID           City     Company  KM_Travelled  \
# 359387        10440101        52392  WASHINGTON DC  Yellow Cab          4.80
# 359388        10440104        53286  WASHINGTON DC  Yellow Cab          8.40
# 359389        10440105        52265  WASHINGTON DC  Yellow Cab         27.75
# 359390        10440106        52175  WASHINGTON DC  Yellow Cab          8.80
# 359391        10440107        52917  WASHINGTON DC  Yellow Cab         12.76
#
#         Price_Charged  Cost_of_Trip  Month  Year Payment_Mode Gender  Age  \
# 359387          69.24       63.3600      1  2018         Cash   Male   24
# 359388         113.75      106.8480      1  2018         Cash   Male   32
# 359389         437.07      349.6500      1  2018         Cash   Male   56
# 359390         146.19      114.0480      1  2018         Card   Male   32
# 359391         191.58      177.6192      1  2018         Card   Male   20
#
#         Income Population      Users  Margins
# ...

# %%
df = data[['KM_Travelled','Price_Charged','Cost_of_Trip','Month','Year','Age','Income','Margins']]
df.corr()
# Out:
#                KM_Travelled  Price_Charged  Cost_of_Trip     Month      Year  \
# KM_Travelled       1.000000       0.835753      0.981848 -0.001773 -0.001094
# Price_Charged      0.835753       1.000000      0.859812 -0.059639 -0.036903
# Cost_of_Trip       0.981848       0.859812      1.000000 -0.008309 -0.001766
# Month             -0.001773      -0.059639     -0.008309  1.000000 -0.033169
# Year              -0.001094      -0.036903     -0.001766 -0.033169  1.000000
# Age               -0.000369      -0.003084     -0.000189 -0.002376 -0.000497
# Income            -0.000544       0.003228     -0.000633  0.000585 -0.001679
# Margins            0.462768       0.864154      0.486056 -0.093886 -0.061420
#
#                     Age    Income   Margins
# KM_Travelled  -0.000369 -0.000544  0.462768
# Price_Charged -0.003084  0.003228  0.864154
# Cost_of_Trip  -0.000189 -0.000633  0.486056
# Month         -0.002376  0.000585 -0.093886
# Year          -0.000497 -0.001679 -0.061420
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,vmin=-1,vmax=1,cmap='coolwarm')
plt.show()

# %% [markdown]
# > **Margins and price charged are correlated**

# %%
city_m = data[data.Month==12].groupby('City').Margins.mean()
city_m
# Out:
# City
# ATLANTA GA         96.252930
# AUSTIN TX          91.891400
# BOSTON MA          62.360750
# CHICAGO IL         52.396687
# DALLAS TX         109.465216
# DENVER CO         111.138893
# LOS ANGELES CA     81.752667
# MIAMI FL          100.150911
# NASHVILLE TN       81.459593
# NEW YORK NY       258.421581
# ORANGE COUNTY      76.134553
# PHOENIX AZ         76.922806
# PITTSBURGH PA      57.105846
# SACRAMENTO CA      27.119039
# SAN DIEGO CA       70.382592
# SEATTLE WA         76.515311
# SILICON VALLEY    167.087114
# TUCSON AZ          84.105100
# WASHINGTON DC      62.742899
# Name: Margins, dtype: float64

# %%
dt1 = data[(data.Company=='Pink Cab')&(data.City=='NEW YORK NY')].groupby(['Year','Month']).Margins.mean()
dt2 = data[(data.Company=='Yellow Cab')&(data.City=='NEW YORK NY')].groupby(['Year','Month']).Margins.mean()
dd1 = pd.DataFrame({'MarginsPink':dt1.values,'TransactionsPink':data[data.Company=='Pink Cab'].groupby(['Year','Month']).Transaction_ID.count().values})
dd2 = pd.DataFrame({'MarginsYellow':dt2.values,'TransactionsYellow':data[data.Company=='Yellow Cab'].groupby(['Year','Month']).Transaction_ID.count().values})

# %% [markdown]
# ##Monthly Margins

# %% [markdown]
# ###For Pink Cab

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=dd1.TransactionsPink,y=dd1.MarginsPink,color='magenta')
plt.show()

# %% [markdown]
# > **There is an increase in margin with increase in transactions**

# %% [markdown]
# ###For Yellow Cab

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=dd2.TransactionsYellow,y=dd2.MarginsYellow,color='orange')
plt.show()

# %% [markdown]
# > **There is an decrease in margin with increase in transactions**

# %% [markdown]
# ##Hypothesis Test

# %% [markdown]
# ###For Pink Cab

# %%
a = data[(data.Gender=='Female')&(data.Company=='Pink Cab')].groupby('Transaction_ID').Margins.mean()
b = data[(data.Gender=='Male')&(data.Company=='Pink Cab')].groupby('Transaction_ID').Margins.mean()
print(a.shape[0],b.shape[0])

from scipy import stats
_, p_value = stats.ttest_ind(a.values,b=b.values,equal_var=True)
if(p_value<0.05):
    print('Alternate hypothesis accepted - There is difference')
else:
    print('Null hypothesis accepted - No difference')
    
print('P value: ', p_value)
# Out:
# 37480 47231
# Null hypothesis accepted - No difference
# P value:  0.11515305900425798

# %% [markdown]
# > **No difference in margin between both gender customers**

# %% [markdown]
# ###For Yellow Cab

# %%
a = data[(data.Gender=='Female')&(data.Company=='Yellow Cab')].groupby('Transaction_ID').Margins.mean()
b = data[(data.Gender=='Male')&(data.Company=='Yellow Cab')].groupby('Transaction_ID').Margins.mean()
print(a.shape[0],b.shape[0])

from scipy import stats
_, p_value = stats.ttest_ind(a.values,b=b.values,equal_var=True)
if(p_value<0.05):
    print('Alternate hypothesis accepted - Statistical difference')
else:
    print('Null hypothesis accepted - No statistical difference')
    
print('P value is ', p_value)
# Out:
# 116000 158681
# Alternate hypothesis accepted - Statistical difference
# P value is  6.060473042494144e-25

# %% [markdown]
# ##Margins per Age

# %%
data[data.Age<=50].groupby('Company').Margins.mean()
data[data.Age>50].groupby('Company').Margins.mean()
# Out:
# Company
# Pink Cab       62.053044
# Yellow Cab    155.855885
# Name: Margins, dtype: float64

# %% [markdown]
# ###For Pink Cab

# %%
a = data[(data.Age<=50)&(data.Company=='Pink Cab')].groupby('Transaction_ID').Margins.mean()
b = data[(data.Age>50)&(data.Company=='Pink Cab')].groupby('Transaction_ID').Margins.mean()
print(a.shape[0],b.shape[0])

from scipy import stats
_, p_value = stats.ttest_ind(a.values,b=b.values,equal_var=True)
if(p_value<0.05):
    print('Alternate hypothesis accepted - There is difference')
else:
    print('Null hypothesis accepted - No difference')
    
print('P value is ', p_value)
# Out:
# 71228 13483
# We accept null hypothesis that theres no difference
# P value is  0.32817487547980695

# %% [markdown]
# ###For Yellow Cab

# %%
a = data[(data.Age<=50)&(data.Company=='Yellow Cab')].groupby('Transaction_ID').Margins.mean()
b = data[(data.Age>50)&(data.Company=='Yellow Cab')].groupby('Transaction_ID').Margins.mean()
print(a.shape[0],b.shape[0])

from scipy import stats
_, p_value = stats.ttest_ind(a.values,b=b.values,equal_var=True)
if(p_value<0.05):
    print('Alternate hypothesis accepted - There is difference')
else:
    print('Null hypothesis accepted - No difference')
    
print('P value is ', p_value)
# Out:
# 231480 43201
# Alternate hypothesis accepted - There is difference
# P value is  6.494256817799368e-09

# %% [markdown]
# > **Yellow Cabs gives discount to people aged over 50**
#
# > **There is difference in margins for cash and card payers**

# %%
a = data[(data.Payment_Mode=='Cash')&(data.Company=='Pink Cab')].groupby('Transaction_ID').Margins.mean()
b = data[(data.Payment_Mode=='Card')&(data.Company=='Pink Cab')].groupby('Transaction_ID').Margins.mean()


_, p_value = stats.ttest_ind(a.values,b=b.values,equal_var=True)
if(p_value<0.05):
    print('Alternate hypothesis accepted - There is difference')
else:
    print('Null hypothesis accepted - No difference')
    
print('P value is ', p_value)
# Out:
# Null hypothesis accepted - No difference
# P value is  0.7900465828793288

# %%
a = data[(data.Payment_Mode=='Cash')&(data.Company=='Yellow Cab')].groupby('Transaction_ID').Margins.mean()
b = data[(data.Payment_Mode=='Card')&(data.Company=='Yellow Cab')].groupby('Transaction_ID').Margins.mean()


_, p_value = stats.ttest_ind(a.values,b=b.values,equal_var=True)
if(p_value<0.05):
    print('Alternate hypothesis accepted - There is difference')
else:
    print('Null hypothesis accepted - No difference')
    
print('P value is ', p_value)
# Out:
# Null hypothesis accepted - No difference
# P value is  0.2933060638298729

# %% [markdown]
# > **No difference in margin regarding mode of payment for both cabs**

# %%
data.head()
# Out:
#    Transaction_ID  Customer_ID        City   Company  KM_Travelled  \
# 0        10000011        29290  ATLANTA GA  Pink Cab         30.45
# 1        10000012        27703  ATLANTA GA  Pink Cab         28.62
# 2        10000013        28712  ATLANTA GA  Pink Cab          9.04
# 3        10000014        28020  ATLANTA GA  Pink Cab         33.17
# 4        10000015        27182  ATLANTA GA  Pink Cab          8.73
#
#    Price_Charged  Cost_of_Trip  Month  Year Payment_Mode Gender  Age  Income  \
# 0         370.95       313.635      1  2016         Card   Male   28   10813
# 1         358.52       334.854      1  2016         Card   Male   27    9237
# 2         125.20        97.632      1  2016         Cash   Male   53   11242
# 3         377.40       351.602      1  2016         Cash   Male   23   23327
# 4         114.62        97.776      1  2016         Card   Male   33    8536
#
#   Population     Users  Margins
# 0   814,885    24,701    57.315
# 1   814,885    24,701    23.666
# ...

# %%
data.to_csv('MastedData.csv', index=False)
